# %%
import pandas as pd
import numpy as np

file='pokemon.csv'
df=pd.read_csv(file)
df

# NaN -> missing values
#numerical->regression   categorical->classification
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
df.head(10)
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# ...

# %%
df.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.shape # gives rows and columns
# Out:
# (800, 12)

# %%
df.info()   # name->799 values nd 1 is missing out of 800 rows #->has all serial nos i.e 800 Type1->has all the 800 values so on....
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.isnull()   #false->not missing true->missing
# Out:
#          #   Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    False  False   False   False  False   False    False    False    False
# 1    False  False   False   False  False   False    False    False    False
# 2    False  False   False   False  False   False    False    False    False
# 3    False  False   False   False  False   False    False    False    False
# 4    False  False   False    True  False   False    False    False    False
# ..     ...    ...     ...     ...    ...     ...      ...      ...      ...
# 795  False  False   False   False  False   False    False    False    False
# 796  False  False   False   False  False   False    False    False    False
# 797  False  False   False   False  False   False    False    False    False
# 798  False  False   False   False  False   False    False    False    False
# 799  False  False   False   False  False   False    False    False    False
#
#      Speed  Generation  Legendary
# ...

# %%
df.isnull().sum()  #name-> has 1 missing value type2->386 missing values it will sum all the trues which have missiong values in isnull()
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.nunique() #It will return the count of unique values and it will help you to decide which features are numerical and categorical i.e type1,type2,generation,legendary can become categorical becoz of small values.If too large values are there like 800,95,799 then it's numerical
# Out:
# #             800
# Name          799
# Type 1         18
# Type 2         18
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %%
df['Name'].unique()
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Mega Venusaur', 'Charmander',
#        'Charmeleon', 'Charizard', 'Mega Charizard X', 'Mega Charizard Y',
#        'Squirtle', 'Wartortle', 'Blastoise', 'Mega Blastoise', 'Caterpie',
#        'Metapod', 'Butterfree', 'Weedle', 'Kakuna', 'Beedrill',
#        'Mega Beedrill', 'Pidgey', 'Pidgeotto', 'Pidgeot', 'Mega Pidgeot',
#        'Rattata', 'Raticate', 'Spearow', 'Fearow', 'Ekans', 'Arbok',
#        'Pikachu', 'Raichu', 'Sandshrew', 'Sandslash', 'Nidoran♀',
#        'Nidorina', 'Nidoqueen', 'Nidoran♂', 'Nidorino', 'Nidoking',
#        'Clefairy', 'Clefable', 'Vulpix', 'Ninetales', 'Jigglypuff',
#        'Wigglytuff', 'Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume',
#        'Paras', 'Parasect', 'Venonat', 'Venomoth', 'Diglett', 'Dugtrio',
#        'Meowth', 'Persian', 'Psyduck', 'Golduck', 'Mankey', nan,
#        'Growlithe', 'Arcanine', 'Poliwag', 'Poliwhirl', 'Poliwrath',
# ...

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df.describe() #works only on numeric features.for eg Name wont be considered becoz its string likewise
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# # Column Operations

# %%
df['Name'] #1d
# Out:
# 0           Bulbasaur
# 1             Ivysaur
# 2            Venusaur
# 3       Mega Venusaur
# 4          Charmander
#             ...
# 795           Diancie
# 796      Mega Diancie
# 797    Hoopa Confined
# 798     Hoopa Unbound
# 799         Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name']]  #to make it 2d from 1d
# Out:
#                Name
# 0         Bulbasaur
# 1           Ivysaur
# 2          Venusaur
# 3     Mega Venusaur
# 4        Charmander
# ..              ...
# 795         Diancie
# 796    Mega Diancie
# 797  Hoopa Confined
# 798   Hoopa Unbound
# 799       Volcanion
#
# [800 rows x 1 columns]

# %%
df[['Name','Type 1']]  # to see 2 columns together
# Out:
#                Name   Type 1
# 0         Bulbasaur    Grass
# 1           Ivysaur    Grass
# 2          Venusaur    Grass
# 3     Mega Venusaur    Grass
# 4        Charmander     Fire
# ..              ...      ...
# 795         Diancie     Rock
# 796    Mega Diancie     Rock
# 797  Hoopa Confined  Psychic
# 798   Hoopa Unbound  Psychic
# 799       Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
#adding new column to dataframe
df['Difference']=df['Attack']-df['Defense']

# %%
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  Difference
# 0     45           1      False           0
# 1     60           1      False          -1
# 2     80           1      False          -1
# 3     80           1      False         -23
# 4     65           1      False           9

# %%
#Removing any column

df.drop(['Difference'],axis=1)
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df #After removing difference column if we try to print df again difference column is still there
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Difference
# ...

# %%
df.drop(['Difference'],inplace=True,axis=1)  #to rectify above error and make changes visible we will use inplace

# %%
df  # now difference column won't appear
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %% [markdown]
# # Row Operations

# %%
df.iloc[0]   #it will give all the information at 0th row
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
#slicing
df.iloc[4:20,:5]  # rows-> start 4 till 19th row  columns-> start 0->4th column
# Out:
#      #              Name Type 1  Type 2  HP
# 4    5        Charmander   Fire     NaN  39
# 5    6        Charmeleon   Fire     NaN  58
# 6    7         Charizard   Fire  Flying  78
# 7    8  Mega Charizard X   Fire  Dragon  78
# 8    9  Mega Charizard Y   Fire  Flying  78
# 9   10          Squirtle  Water     NaN  44
# 10  11         Wartortle  Water     NaN  59
# 11  12         Blastoise  Water     NaN  79
# 12  13    Mega Blastoise  Water     NaN  79
# 13  14          Caterpie    Bug     NaN  45
# 14  15           Metapod    Bug     NaN  50
# 15  16        Butterfree    Bug  Flying  60
# 16  17            Weedle    Bug  Poison  40
# 17  18            Kakuna    Bug  Poison  45
# 18  19          Beedrill    Bug  Poison  65
# 19  20     Mega Beedrill    Bug  Poison  65

# %%
# remove particular rows
df.drop(index=2,inplace=True,axis=0)

df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# 5      6      Charmeleon     Fire     NaN  58      64       58       80
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
#to remove particular column
df.drop(['#'],inplace=True,axis=1)

# %%
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# 5        Charmeleon     Fire     NaN  58      64       58       80       65
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# # Rename

# %%
df.rename(columns={'HP':'Health Points'},inplace=True)

# %%
df.head()
# Out:
#             Name Type 1  Type 2  Health Points  Attack  Defense  Sp. Atk  \
# 0      Bulbasaur  Grass  Poison             45      49       49       65
# 1        Ivysaur  Grass  Poison             60      62       63       80
# 3  Mega Venusaur  Grass  Poison             80     100      123      122
# 4     Charmander   Fire     NaN             39      52       43       60
# 5     Charmeleon   Fire     NaN             58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %% [markdown]
# # Set_Index()

# %%
df=df.set_index('Name')  #to make our own indexing instead of default raw indexing (i.e 0,1,2....) now Name is not a row it has become index

# %%
df.head()
# Out:
#               Type 1  Type 2  Health Points  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur      Grass  Poison             45      49       49       65
# Ivysaur        Grass  Poison             60      62       63       80
# Mega Venusaur  Grass  Poison             80     100      123      122
# Charmander      Fire     NaN             39      52       43       60
# Charmeleon      Fire     NaN             58      64       58       80
#
#                Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur           65     45           1      False
# Ivysaur             80     60           1      False
# Mega Venusaur      120     80           1      False
# Charmander          50     65           1      False
# Charmeleon          65     80           1      False

# %%
df.loc['Ivysaur']   # now that we have created our own indexing we will use loc to access the records instead of iloc
# Out:
# Type 1            Grass
# Type 2           Poison
# Health Points        60
# Attack               62
# Defense              63
# Sp. Atk              80
# Sp. Def              80
# Speed                60
# Generation            1
# Legendary         False
# Name: Ivysaur, dtype: object

# %% [markdown]
# # Reset Index

# %%
df.reset_index()  # to reset the index i.e Name back to default index
# Out:
#                Name   Type 1  Type 2  Health Points  Attack  Defense  Sp. Atk  \
# 0         Bulbasaur    Grass  Poison             45      49       49       65
# 1           Ivysaur    Grass  Poison             60      62       63       80
# 2     Mega Venusaur    Grass  Poison             80     100      123      122
# 3        Charmander     Fire     NaN             39      52       43       60
# 4        Charmeleon     Fire     NaN             58      64       58       80
# ..              ...      ...     ...            ...     ...      ...      ...
# 794         Diancie     Rock   Fairy             50     100      150      100
# 795    Mega Diancie     Rock   Fairy             50     160      110      160
# 796  Hoopa Confined  Psychic   Ghost             80     110       60      150
# 797   Hoopa Unbound  Psychic    Dark             80     160       60      170
# 798       Volcanion     Fire   Water             80     110      120      130
#
# ...

# %% [markdown]
# # Q. How many type 1 pokemons are there

# %%
type_1=df['Type 1'].nunique()
print("No Of Type 1 pokemons:",type_1)
# Out:
# No Of Type 1 pokemons: 18

# %% [markdown]
# # Q. How many type 2 pokemons are there

# %%
type_2=df['Type 2'].nunique()
print("No Of Type 2 pokemons:",type_2)
# Out:
# No Of Type 2 pokemons: 18

# %% [markdown]
# # Q. What are the different variants of Type 1

# %%
type_1_names=df['Type 1'].unique()
print("Different Variants Of Type 1 pokemons:",type_1_names)
# Out:
# Different Variants Of Type 1 pokemons: ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']

# %% [markdown]
# # Values count

# %%
# To show how many times a particular value is repeated.for eg->water is repeated 112 times
type_1_count=df['Type 1'].value_counts()
type_1_count
# Out:
# Water       112
# Normal       98
# Grass        69
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Defense'].max()
# Out:
# 230

# %%
df['Defense'].idxmax()   #it will give the row number of maximum value. here 230 max value of defence will be at 224th row
# Out:
# 224

# %%
df['Defense'].min()
# Out:
# 5

# %%
df['Defense'].idxmin()
# Out:
# 121
